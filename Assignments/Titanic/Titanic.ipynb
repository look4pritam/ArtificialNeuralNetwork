# %% [markdown]
# <a href="https://colab.research.google.com/github/look4pritam/ArtificialNeuralNetwork/blob/master/Assignments/Titanic/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment to build a model for Titanic Survival Prediction**
#
# ## **Description of Dataset fields in Titanic dataset**
#
# - survival - Survival (0 = No; 1 = Yes)
# - class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - name - Name
# - sex - Sex
# - age - Age
# - sibsp - Number of Siblings/Spouses Aboard
# - parch - Number of Parents/Children Aboard
# - ticket - Ticket Number
# - fare - Passenger Fare
# - cabin - Cabin
# - embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
#
# **Note: All the data operations done on Train dataset MUST also be done on Test dataset**

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Importing raw train and test set.**
#
# **Printing shapes of train and test data**
#
# **Printing number of missing data in train and test Dataset**

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')
y_test = pd.read_csv('/content/test_output.csv')

print("Shape of train data",train.shape)
print("Shape of test data",test.shape)

# %%
print("Number of Missing data in train dataset for each column")
print(train.isnull().sum())

# %%
print("Number of Missing data in test dataset for each column")
print(test.isnull().sum())

# %% [markdown]
# **Dropping Columns:**
# - Drop columns which are not used for training (irrelevant data).
# - Use - train.drop(['column_name'], axis=1, inplace = True)
#
# #MODIFY THIS CODE

# %%
#train.drop(['column_name'], axis=1, inplace = True)
#print(train)
#print(train.shape)

# %% [markdown]
# **Finding mean of a column**
# example:
#
# avg = train['column_name'].astype('float').mean(axis=0)
#
# #MODIFY THIS CODE

# %%
#avg = train['column_name'].astype('float').mean(axis=0)
#test_avg= test['column_name'].astype('float').mean(axis=0)
#print(avg)
#print(test_avg)

# %% [markdown]
# **Clean Data**
#
# The replace() method replaces a specified phrase with another specified phrase.
#
# Syntax: string.replace(oldvalue, newvalue, count, inplace = True)
#
# eg:
#
# txt = "I like bananas"
#
#
#
# txt.replace("bananas", "apples",  inplace = True) #To replace bananas with apples in txt
#
# print(txt) #I like apples
#
#
# TO REPLACE MISSING VALUES
#
# eg train['column_name'].replace(np.nan, var, inplace = True)
# here all the missing values will be replace with value of variable var
#
# #MODIFY THIS CODE

# %% [markdown]
# **Note: All the data operations done on Train dataset MUST also be done on Test dataset**

# %%
train['Sex'].replace('female', 1, inplace = True)
train['Sex'].replace('male', 0, inplace = True)

# %%
test['Sex'].replace('female', 1, inplace = True)
test['Sex'].replace('male', 0, inplace = True)

# %% [markdown]
# Above example shows how to replace Sex - (female, male) into (1, 0) as categorical numbers.
# ## Do the same for other required feature columns.

# %%
# Feature
# Train
# Test

# %%
#print(train[train.isnull().any(axis=1)]) #This command will print all the rows with null value to analyse code
#print("Number of Missing data in train dataset for each column")
#print(train.isnull().sum())
#print("Number of Missing data in test dataset for each column")
#print(test.isnull().sum())

# %% [markdown]
# **Splitting the dataset into the Training set and Test set**
# # MODIFY THIS CODE

# %% [markdown]
# **Note: All the data operations done on Train dataset MUST also be done on Test dataset**
#
# Slicing in python means taking elements from one given index to another given index.
# - 1D array - output_array = input_array[start_index:end_index].values
# - 2D array - output_array = input_array[y_start_index:y_end_index,  x_start_index:x_end_index].values
#
# See following links for details
# - [NumPy Introduction](https://www.w3schools.com/python/numpy/numpy_intro.asp)
# - [NumPy Getting Started](https://www.w3schools.com/python/numpy/numpy_getting_started.asp)
# - [NumPy Creating Arrays](https://www.w3schools.com/python/numpy/numpy_creating_arrays.asp)
# - [NumPy Array Indexing](https://www.w3schools.com/python/numpy/numpy_array_indexing.asp)
# - [NumPy Array Slicing](https://www.w3schools.com/python/numpy/numpy_array_slicing.asp)

# %%
X_train = train.iloc[:,2:].values
X_test = test.iloc[:,:].values

# %%
y_train = train.iloc[:,1].values
y_test = y_test.iloc[:,1].values

# %% [markdown]
# **FEATURE SCALING**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)

# %%
X_test = sc.transform(X_test)

# %% [markdown]
# **Splitting data into train and validation dataset**

# %%
from sklearn.model_selection import train_test_split
xtrain, xval, ytrain, yval = train_test_split(X_train,y_train, test_size = 0.25,  random_state=42)

# %% [markdown]
# **Importing Libraries required to train the model**

# %%
import numpy as np

from keras.callbacks import ModelCheckpoint,TensorBoard
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten

from keras import regularizers

import tensorflow as tf
from keras import backend as K
from keras.models import Model
from keras.layers import Input

from keras.optimizers import Adam, SGD

np.random.seed(123) # for reproducibility

# %% [markdown]
# **Defining the Model**
#
# Try different layers such as
#
# * Dense(no_of_units,activation="sigmoid",kernel_regularizer=regularizers.L1(x))
#
# Try different activations like relu,tanh etc.
#
# Try regularizers also(L1 OR L2) and different values of x
# * Dropout(x) where can be number between 0.25 to 0.5 #Place this layer after dense or convolution layer, but not the last layer
#
# #MODIFY THIS CODE

# %% [markdown]
# - Add or delete more layers with different combinations of activation functions, and regularizers

# %%
model=Sequential()
model.add(Dense(1,activation="sigmoid"))

# %% [markdown]
# **Setting up hyperparameters**
#
# #MODIFY THIS CODE

# %%
nepochs =
batchsize =
learningrate =

# %%
#Try different optimizers like Adam, SGD etc
toptimizer = Adam(learning_rate=learningrate)

# %% [markdown]
# **Compile the code and run backpropogation**

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="./logs")

# %%
model.compile(optimizer = toptimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model.fit(xtrain, ytrain,validation_data=(xval, yval), shuffle=True,
          batch_size = batchsize, epochs = nepochs,callbacks=[tensorboard_callback])

# %% [markdown]
# **Visualize the training graphs.**

# %%
# %reload_ext tensorboard
# %tensorboard --logdir logs

# %% [markdown]
# **EVALUATE THE MODEL**

# %%
score = model.evaluate(X_test, y_test, verbose=1)
print('Loss = ',score[0])
print('Accuracy Score = ',score[1])
